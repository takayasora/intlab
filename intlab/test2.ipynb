# %% [markdown]
# # 単発テスト

# %%
# sapnet.pyをインポート
from sapnet import sapnet

# 準備
df = sapnet.example_dataframe()

# ハイパーパラメータ
stimulus = 1
first_stimulus_value = 1.0

# 計算
df = sapnet.stimulus_calc(df,stimulus,first_stimulus_value)
# Out:
# DEBUG : (0/8)Generating dataframe for dataframe.
# DEBUG : (0/8)Converting array to DataFrame
# INFO  : Sapnet's algorithm, Start the calculations.
# INFO  : (1/10)Generating stimulus pair list for stimulus 1
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[1, 2], [1, 6], [1, 4], [1, 7]]
# DEBUG : (3/10)Removing already pairs [1, 2] [2, 1]
# DEBUG : (3/10)Removing already pairs [1, 6] [6, 1]
# DEBUG : (3/10)Removing already pairs [1, 4] [4, 1]
# DEBUG : (3/10)Removing already pairs [1, 7] [7, 1]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[2, 1], [2, 3], [2, 5]]
# DEBUG : (3/10)Removing already pairs [2, 3] [3, 2]
# DEBUG : (3/10)Removing already pairs [2, 5] [5, 2]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[6, 1], [6, 5], [6, 7]]
# DEBUG : (3/10)Removing already pairs [6, 5] [5, 6]
# DEBUG : (3/10)Removing already pairs [6, 7] [7, 6]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[4, 5], [4, 3], [4, 1]]
# DEBUG : (3/10)Removing already pairs [4, 5] [5, 4]
# DEBUG : (3/10)Removing already pairs [4, 3] [3, 4]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[7, 5], [7, 1], [7, 6], [7, 3]]
# DEBUG : (3/10)Removing already pairs [7, 5] [5, 7]
# DEBUG : (3/10)Removing already pairs [7, 3] [3, 7]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[3, 4], [3, 2], [3, 7]]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[5, 4], [5, 7], [5, 6], [5, 2]]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[5, 4], [5, 7], [5, 6], [5, 2]]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[7, 5], [7, 1], [7, 6], [7, 3]]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[5, 4], [5, 7], [5, 6], [5, 2]]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[3, 4], [3, 2], [3, 7]]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[5, 4], [5, 7], [5, 6], [5, 2]]
# DEBUG : (2/10)Calculating next_Allpair
# DEBUG : (2/10)Calculating next_Allpair [[3, 4], [3, 2], [3, 7]]
# INFO  : (3/10)Generating stimulus pair list [[1, 2], [1, 6], [1, 4], [1, 7], [2, 3], [2, 5], [6, 5], [6, 7], [4, 5], [4, 3], [7, 5], [7, 3]]
# DEBUG : (4/10)Creating last dataframe for stimulus 1 -> [1.0, 0, 0, 0, 0, 0, 0]
# DEBUG : (5/10)Counting paths for stimulus 1
# DEBUG : (5/10)Counting paths for stimulus 1 --> 4
# DEBUG : (6/10)Calculating path weight for stimulus 1 and receive 2
# DEBUG : (6/10)Calculating path weight for stimulus 1 -> 2 --> 0.1
# DEBUG : (7/10)calculation stimulus value for pairA( 1 )and pairB( 2 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0, 0, 0, 0, 0, 0]
# DEBUG : (7/10)pickup last value pair( 1 ): 1.0
# DEBUG : (7/10)Calculation -> 1/ 4 * 1.0  * exp(- 0.1 )
# DEBUG : (7/10)Calculation ->  0.22620935450898988
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0, 0, 0, 0, 0]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  1  to  2 , adding  0.22620935450898988 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 1
# DEBUG : (5/10)Counting paths for stimulus 1 --> 4
# DEBUG : (6/10)Calculating path weight for stimulus 1 and receive 6
# DEBUG : (6/10)Calculating path weight for stimulus 1 -> 6 --> 0.3
# DEBUG : (7/10)calculation stimulus value for pairA( 1 )and pairB( 6 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0, 0, 0, 0, 0]
# DEBUG : (7/10)pickup last value pair( 1 ): 1.0
# DEBUG : (7/10)Calculation -> 1/ 4 * 1.0  * exp(- 0.3 )
# DEBUG : (7/10)Calculation ->  0.18520455517042947
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0, 0, 0, 0.18520455517042947, 0]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  1  to  6 , adding  0.18520455517042947 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 1
# DEBUG : (5/10)Counting paths for stimulus 1 --> 4
# DEBUG : (6/10)Calculating path weight for stimulus 1 and receive 4
# DEBUG : (6/10)Calculating path weight for stimulus 1 -> 4 --> 0.4
# DEBUG : (7/10)calculation stimulus value for pairA( 1 )and pairB( 4 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0, 0, 0, 0.18520455517042947, 0]
# DEBUG : (7/10)pickup last value pair( 1 ): 1.0
# DEBUG : (7/10)Calculation -> 1/ 4 * 1.0  * exp(- 0.4 )
# DEBUG : (7/10)Calculation ->  0.16758001150890983
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0, 0.16758001150890983, 0, 0.18520455517042947, 0]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  1  to  4 , adding  0.16758001150890983 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 1
# DEBUG : (5/10)Counting paths for stimulus 1 --> 4
# DEBUG : (6/10)Calculating path weight for stimulus 1 and receive 7
# DEBUG : (6/10)Calculating path weight for stimulus 1 -> 7 --> 0.5
# DEBUG : (7/10)calculation stimulus value for pairA( 1 )and pairB( 7 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0, 0.16758001150890983, 0, 0.18520455517042947, 0]
# DEBUG : (7/10)pickup last value pair( 1 ): 1.0
# DEBUG : (7/10)Calculation -> 1/ 4 * 1.0  * exp(- 0.5 )
# DEBUG : (7/10)Calculation ->  0.15163266492815836
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0, 0.16758001150890983, 0, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  1  to  7 , adding  0.15163266492815836 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 2
# DEBUG : (5/10)Counting paths for stimulus 2 --> 3
# DEBUG : (6/10)Calculating path weight for stimulus 2 and receive 3
# DEBUG : (6/10)Calculating path weight for stimulus 2 -> 3 --> 0.4
# DEBUG : (7/10)calculation stimulus value for pairA( 2 )and pairB( 3 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0, 0.16758001150890983, 0, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (7/10)pickup last value pair( 2 ): 0.22620935450898988
# DEBUG : (7/10)Calculation -> 1/ 3 * 0.22620935450898988  * exp(- 0.4 )
# DEBUG : (7/10)Calculation ->  0.05054422164271945
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  2  to  3 , adding  0.05054422164271945 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 2
# DEBUG : (5/10)Counting paths for stimulus 2 --> 3
# DEBUG : (6/10)Calculating path weight for stimulus 2 and receive 5
# DEBUG : (6/10)Calculating path weight for stimulus 2 -> 5 --> 0.6
# DEBUG : (7/10)calculation stimulus value for pairA( 2 )and pairB( 5 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (7/10)pickup last value pair( 2 ): 0.22620935450898988
# DEBUG : (7/10)Calculation -> 1/ 3 * 0.22620935450898988  * exp(- 0.6 )
# DEBUG : (7/10)Calculation ->  0.04138210864928413
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.04138210864928413, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  2  to  5 , adding  0.04138210864928413 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 6
# DEBUG : (5/10)Counting paths for stimulus 6 --> 3
# DEBUG : (6/10)Calculating path weight for stimulus 6 and receive 5
# DEBUG : (6/10)Calculating path weight for stimulus 6 -> 5 --> 0.4
# DEBUG : (7/10)calculation stimulus value for pairA( 6 )and pairB( 5 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.04138210864928413, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (7/10)pickup last value pair( 6 ): 0.18520455517042947
# DEBUG : (7/10)Calculation -> 1/ 3 * 0.18520455517042947  * exp(- 0.4 )
# DEBUG : (7/10)Calculation ->  0.04138210864928413
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.04138210864928413, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  6  to  5 , adding  0.04138210864928413 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 6
# DEBUG : (5/10)Counting paths for stimulus 6 --> 3
# DEBUG : (6/10)Calculating path weight for stimulus 6 and receive 7
# DEBUG : (6/10)Calculating path weight for stimulus 6 -> 7 --> 0.6
# DEBUG : (7/10)calculation stimulus value for pairA( 6 )and pairB( 7 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.04138210864928413, 0.18520455517042947, 0.15163266492815836]
# DEBUG : (7/10)pickup last value pair( 6 ): 0.18520455517042947
# DEBUG : (7/10)Calculation -> 1/ 3 * 0.18520455517042947  * exp(- 0.6 )
# DEBUG : (7/10)Calculation ->  0.033880804978383264
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.04138210864928413, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  6  to  7 , adding  0.033880804978383264 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 4
# DEBUG : (5/10)Counting paths for stimulus 4 --> 3
# DEBUG : (6/10)Calculating path weight for stimulus 4 and receive 5
# DEBUG : (6/10)Calculating path weight for stimulus 4 -> 5 --> 0.1
# DEBUG : (7/10)calculation stimulus value for pairA( 4 )and pairB( 5 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.04138210864928413, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (7/10)pickup last value pair( 4 ): 0.16758001150890983
# DEBUG : (7/10)Calculation -> 1/ 3 * 0.16758001150890983  * exp(- 0.1 )
# DEBUG : (7/10)Calculation ->  0.05054422164271945
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.05054422164271945, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  4  to  5 , adding  0.05054422164271945 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 4
# DEBUG : (5/10)Counting paths for stimulus 4 --> 3
# DEBUG : (6/10)Calculating path weight for stimulus 4 and receive 3
# DEBUG : (6/10)Calculating path weight for stimulus 4 -> 3 --> 0.2
# DEBUG : (7/10)calculation stimulus value for pairA( 4 )and pairB( 3 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0.05054422164271945, 0.16758001150890983, 0.05054422164271945, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (7/10)pickup last value pair( 4 ): 0.16758001150890983
# DEBUG : (7/10)Calculation -> 1/ 3 * 0.16758001150890983  * exp(- 0.2 )
# DEBUG : (7/10)Calculation ->  0.045734303007835535
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.045734303007835535, 0.16758001150890983, 0.05054422164271945, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  4  to  3 , adding  0.045734303007835535 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 7
# DEBUG : (5/10)Counting paths for stimulus 7 --> 4
# DEBUG : (6/10)Calculating path weight for stimulus 7 and receive 5
# DEBUG : (6/10)Calculating path weight for stimulus 7 -> 5 --> 0.2
# DEBUG : (7/10)calculation stimulus value for pairA( 7 )and pairB( 5 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0.045734303007835535, 0.16758001150890983, 0.05054422164271945, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (7/10)pickup last value pair( 7 ): 0.033880804978383264
# DEBUG : (7/10)Calculation -> 1/ 4 * 0.033880804978383264  * exp(- 0.2 )
# DEBUG : (7/10)Calculation ->  0.0069348142437099915
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.045734303007835535, 0.16758001150890983, 0.0069348142437099915, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  7  to  5 , adding  0.0069348142437099915 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (5/10)Counting paths for stimulus 7
# DEBUG : (5/10)Counting paths for stimulus 7 --> 4
# DEBUG : (6/10)Calculating path weight for stimulus 7 and receive 3
# DEBUG : (6/10)Calculating path weight for stimulus 7 -> 3 --> 0.7
# DEBUG : (7/10)calculation stimulus value for pairA( 7 )and pairB( 3 )
# DEBUG : (7/10)Lastlist before update: [1.0, 0.22620935450898988, 0.045734303007835535, 0.16758001150890983, 0.0069348142437099915, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (7/10)pickup last value pair( 7 ): 0.033880804978383264
# DEBUG : (7/10)Calculation -> 1/ 4 * 0.033880804978383264  * exp(- 0.7 )
# DEBUG : (7/10)Calculation ->  0.004206177458221988
# DEBUG : (7/10)Lastlist after update: [1.0, 0.22620935450898988, 0.004206177458221988, 0.16758001150890983, 0.0069348142437099915, 0.18520455517042947, 0.033880804978383264]
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (9/10)Updating DataFrame
# DEBUG : (9/10)moved from  7  to  3 , adding  0.004206177458221988 .
# DEBUG : (9/10)DataFrame update completed
# DEBUG : (8/10)Make DataFrame graph
# DEBUG : (10/10)Make Gif image completed
